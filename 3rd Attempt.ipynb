# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

dpi = 300

# %%
def current_path():
    print("Current working directory before")
    print(os.getcwd())
    print()
 
current_path()

os.chdir('/Users/paige/Downloads')
current_path()
# Out:
# Current working directory before
# /Users/paige/Downloads
#
# Current working directory before
# /Users/paige/Downloads

# %%
project_dir = r'LocalCrime.csv'
data_dir = project_dir +r'data/'
output_dir = project_dir + r'data/'

# %%
df_filename = 'LocalCrime.csv'
df = pd.read_csv(df_filename, index_col=0)
df_head = df.iloc[:100,:]
columns = list(df.columns)
df
# Out:
#                            State  Months  Population  Violent_crime_total  \
# Agency
# Abilene Police Dept           TX      12      119886                  472
# Akron City Police Dept        OH      12      198390                 1759
# Alexandria Police Dept        VA      12      145892                  243
# Allentown City Police Dept    PA      12      119334                  653
# Amarillo Police Dept          TX      12      196576                 1278
# ...                          ...     ...         ...                  ...
# Wilmington Police Dept        NC      12      109370                  618
# Winston-Salem Police Dept     NC      12      234687                 1556
# Woodbridge Police Dept        NJ      12      100612                  122
# Worcester Police Dept         MA      12      183247                 1758
# Yonkers Police Dept           NY      12      198464                 1133
#
# ...

# %%
fig, ax = plt.subplots(figsize =(13,16))
langs = ['Violent_crime_total', 'Murder_and_manslaughter', 'Forcibel_rape', 'Robbery', 'Burglary']
totals = [472,3,38,127,1037]
ax.bar(langs,totals)
ax.set_title('Abilene Police Dept Different Crime Totals')
ax.set_xlabel('Crime Type')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
fig, ax = plt.subplots(figsize =(8,10))
labels = ['State', 'Population']
handles = ax.plot(x,y)
ax.legend(handles, labels, loc='lower right')
ax.set_title('Population by Lowest 5 Populous States')
ax.set_xlabel('State')
ax.set_ylabel('Population Count')
# Out:
# Text(0, 0.5, 'Population Count')

# %%
fig, ax = plt.subplots(figsize =(16,16))
langs = ['Violent_crime_total', 'Murder_and_manslaughter', 'Forcibel_rape', 'Robbery','Aggravated-assault', 'Property_crime','Burglary','Larceny_theft','Motor-vehicle_theft']
totals = [581,8,33,227,313,5081,926,3153,1002]
ax.bar(langs,totals)
ax.set_title('Chula Vista, CA Different Crime Totals')
ax.set_xlabel('Crime Type')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
